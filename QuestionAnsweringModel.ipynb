# %%
# !pip install SimpleTransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 249 kB 27.0 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 54.9 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 58.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 2.9 MB/s
# ...
#      |████████████████████████████████| 362 kB 38.4 MB/s
# ...
#      |████████████████████████████████| 9.1 MB 62.5 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 60.5 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 101 kB 12.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 52.2 MB/s
# ...
#      |████████████████████████████████| 147 kB 69.5 MB/s
# ...
#      |████████████████████████████████| 181 kB 72.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 212 kB 67.2 MB/s
# ...
#      |████████████████████████████████| 140 kB 74.8 MB/s
# ...

# %%
import logging
import os
import pandas as pd

# %%
df=pd.read_csv('/content/Vastu - Sheet1 (5).csv',sep=',')
print(df.columns.tolist())
df
# Out:
# ['target_text', 'input_text']
#                                           target_text  \
# 0   the safe should be placed in the south west co...
# 1   Clutter and dirt can cause major energy deplet...
# 2   Never place a safe or cash box in kitchen or s...
# 3   Line the interiors of your safe with a red, a ...
# 4   Even in the worst of times, at least leave a s...
# 5   One should ring temple bells and light incense...
# 6   Mirrors should always be placed on the eastern...
# 7   Other than the dressing room and washroom, mir...
# 8   Square and rectangular shapes are preferred in...
# 9   Placing a mirror inside your locker can help i...
# 10  Wherever you place a mirror, make sure that it...
# 11  As per vastu, it is not advisable to place a m...
# 12  The house must tick all the below boxes: • Pra...
# 13  Sleeping with one's head in south is the most ...
# 14  Vastu architecture is an ancient and tradition...
# 15  South-east or ‘Aagneya Kone' is the direction ...
# ...

# %%
df["prefix"]="generate_answers"

# %%
from sklearn.model_selection import train_test_split

# %%
train_df, eval_df = train_test_split(df, test_size=0.05)
#train_df.keys()

# %%
from simpletransformers.t5 import T5Model ,T5Args

model_args=T5Args()
model_args.num_train_epochs = 3
model_args.overwrite_output_dir = True


model = T5Model(
    model_type='t5',
    model_name="t5-base",
    args=model_args,
    use_cuda=False
    
    
)
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:174: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,

# %%
model.train_model(train_df)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3557: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and the tokenizer under the `as_target_tokenizer` context manager to prepare
# your targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, ...)
# with tokenizer.as_target_tokenizer():
#     labels = tokenizer(tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
#   warnings.warn(formatted_warning, FutureWarning)
# ...
# Running Epoch 2 of 3:   0%|          | 0/3 [00:00<?, ?it/s]
# (9, 3.396461804707845)

# %%
result = model.eval_model(eval_df)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3557: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and the tokenizer under the `as_target_tokenizer` context manager to prepare
# your targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, ...)
# with tokenizer.as_target_tokenizer():
#     labels = tokenizer(tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
#   warnings.warn(formatted_warning, FutureWarning)
# Running Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from simpletransformers.t5 import T5Model
import pandas as pd
from pprint import pprint

model_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "max_seq_length": 128,
    "eval_batch_size": 128,
    "num_train_epochs": 1,
    "save_eval_checkpoints": False,
    "use_multiprocessing": False,
    "num_beams": None,
    "do_sample": True,
    "max_length": 50,
    "top_k": 50,
    "top_p": 0.95,
    "num_return_sequences": 3,

}

model = T5Model(model_name='t5-base',model_type='t5', args=model_args)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:174: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,

# %%
preds=model.predict( ["generate_answers " + description for description in eval_df["input_text"].tolist()]
)
# Out:
# Generating outputs:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3557: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and the tokenizer under the `as_target_tokenizer` context manager to prepare
# your targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, ...)
# with tokenizer.as_target_tokenizer():
#     labels = tokenizer(tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
#   warnings.warn(formatted_warning, FutureWarning)
# Decoding outputs:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
answers=eval_df['target_text'].tolist()

# %%
for i,desc in enumerate(eval_df["input_text"].tolist()):
  pprint(desc)
  pprint(preds[i])
# Out:
# 'Where should be your money corner?'
# 'Then, you should be able to use the money you have in your pocket to help'
# 'Keep it Clean'
# 'Keep it Clean and a clean environment.'
